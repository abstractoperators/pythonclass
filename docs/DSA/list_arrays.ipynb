# %%
list_array = [4,5,6,7,8,9]
minimumValue = list_array[0]

for i in  list_array:
    if i < minimumValue:
        minimumValue = i

print('Lowest value', minimumValue)
# Out:
# Lowest value 4

# %%
y = [2,3,4,5,6,7,8]
y.reverse()
y.append(5)
y.sort()
print(y)
# Out:
# [2, 3, 4, 5, 5, 6, 7, 8]
