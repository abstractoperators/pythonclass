# %%
class Robot:
    def __init__(self, name,color, age):
        self.name = name
        self.color = color
        self.age = age

    def introduce_self(self):
        print(f"Hello, my name is {self.name}. and i am {self.color} in color and {self.age} years old.")
    

r1 = Robot("Robo", "Red", 5)    
r1.introduce_self()  
r2 = Robot("Bot", "Blue", 3)
# Out:
# Hello, my name is Robo. and i am Red in color and 5 years old.
# Hello, my name is Bot. and i am Blue in color and 3 years old.

# %%
class Robot:
    def __init__(self, name,color, age):
        self.name = name
        self.color = color
        self.age = age

    def introduce_self(self):
        print(f"Hello, my name is {self.name}. and i am {self.color} in color and {self.age} years old.")


    
class Person:
    def __init__(self, name, personality, isSitting, robot_owned):
        self.name = name
        self.personality = personality
        self.isSitting = isSitting
        self.robot_owned = robot_owned

    def introduce_self(self):
        sitting_status = "sitting" if self.isSitting else "not sitting"
        print(f"Hello, my name is {self.name}. I am {self.personality} and I am currently {sitting_status}. i owned {self.robot_owned}")


    

r1 = Robot("Robo", "Red", 5)    
#r1.introduce_self()  
r2 = Robot("Bot", "Blue", 3)
#r2.introduce_self()
p1 = Person("Alice", "Friendly", True, r2.name)
p2 = Person("Bob", "Reserved", False, r1.name)
p1.introduce_self()
p2.introduce_self()
# Out:
# Hello, my name is Alice. I am Friendly and I am currently sitting. i owned a Bot
# Hello, my name is Bob. I am Reserved and I am currently not sitting. i owned a Robo
