# %%
rgb = ["Red", "Green", "Blue"]
rgba = rgb
id(rgb) == id(rgba)  # they reference the same object

rgba.append("Alph")
rgb
rgba

# %%
fix = [1, 4, 5, 5.5, "list"]
fix[-1]
# Out:
# 'list'

# %%
1+1
# Out:
# 2

# %%
name = []

for letter in "opeyemi-peter":
    name.append(letter.upper())
name
# Out:
# ['O', 'P', 'E', 'Y', 'E', 'M', 'I', '-', 'P', 'E', 'T', 'E', 'R']

# %%
numCount= ["p", "e", "t", "e", "r"]
numCount[-1]
# Out:
# 't'

# %%
s = 'supercalifragilisticexpialidocious'
len(s)
# Out:
# 34

# %%
cubes = [1, 8, 27, 65, 125]
cubes[3] = 64
cubes.append(216)
cubes.append(8**4)
cubes
# Out:
# [1, 8, 27, 64, 125, 216, 4096]

# %%
rgb = ["Red", "Green", "Blue"]
rgba = rgb
rgb.append("Alph")
rgba
# Out:
# ['Red', 'Green', 'Blue', 'Alph']

# %%
newCopy = rgba[:]
newCopy.append("indigo")
newCopy  # ['Red', 'Green', 'Blue', 'Alph', 'indigo']
rgba # ['Red', 'Green', 'Blue', 'Alph']
# Out:
# ['Red', 'Green', 'Blue', 'Alph', 'indigo']

# %%
# Fibonacci series:
# the sum of two elements defines the next
a, b = 0, 1
while a < 10:
    print(a)
    a, b = b, a+b
# Out:
# 0
# 1
# 1
# 2
# 3
# 5
# 8
